# %% [markdown]
# # Look at microscopy images from multiple panels

# %%
from image_preprocessing import Plot4Channel
import tifffile as tiff
import matplotlib.pyplot as plt
from plotting_cell_image import MakeCompositeImage

# %% [markdown]
# ## Unprocessed

# %%
A1 = tiff.imread("images/test_images/A1_FOV01_Z100.tif")
Plot4Channel(A1)

# %%
A4 = tiff.imread("images/test_images/A4_FOV00_Z000.tif")
Plot4Channel(A4)

# %%
B1 = tiff.imread("images/test_images/B1_FOV00_Z000.tif")
Plot4Channel(B1)

# %%
C3 = tiff.imread("images/test_images/C3_FOV00_Z000.tif")
Plot4Channel(C3)

# %% [markdown]
# ## Example Predictions

# %%
b1_pred = tiff.imread(b2_test)
print(b1_pred.shape)

Plot4Channel(b1_pred)

# %%
b2_test = "images/test_pred/B2_FOV00_Z075_pr_pred.tif"

b2_pred = tiff.imread(b2_test)
print(b2_pred.shape)

Plot4Channel(b2_pred)
# Out:
# (4, 2189, 2189)

# %%
composite = MakeCompositeImage(b2_pred, ['black', 'red', 'limegreen', 'darkblue'], channel_order=[3, 1, 2, 0])
plt.imshow(composite)
plt.show()

# %%
b2_act = tiff.imread("images/test_pred/B2_FOV00_Z075_pr.tif")
print(b2_act.shape)

Plot4Channel(b2_act)
# Out:
# (4, 2189, 2189)

# %%
composite = MakeCompositeImage(b2_act, ['black', 'red', 'limegreen', 'darkblue'], channel_order=[3, 1, 2, 0])
plt.imshow(composite)
plt.show()

# %%
b3_test = "images/test_pred/B3_FOV00_Z033_pr_pred.tif"

b3_pred = tiff.imread(b3_test)
print(b3_pred.shape)

Plot4Channel(b3_pred)
# Out:
# (4, 2189, 2189)

# %%
composite = MakeCompositeImage(b3_pred, ['black', 'red', 'limegreen', 'darkblue'], channel_order=[3, 1, 2, 0])
plt.imshow(composite)
plt.show()

# %%
# original
b3_actual = "images/test_pred/B3_FOV00_Z033_pr.tif"

b3_act = tiff.imread(b3_actual)
print(b3_act.shape)

Plot4Channel(b3_act)
# Out:
# (4, 2189, 2189)

# %%
composite = MakeCompositeImage(b3_act, ['black', 'red', 'limegreen', 'darkblue'], channel_order=[3, 1, 2, 0])
plt.imshow(composite)
plt.show()
