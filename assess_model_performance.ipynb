# %% [markdown]
# # Predict Test Set Images

# %%
from model import NeuroUNET
import torch
from pathlib import Path
from inference import PredictTestSet, PearsonCorrelationTestSet

# %% [markdown]
# ## B1 Best Checkpoint

# %%
B1_model = NeuroUNET()    # create model instance
state_dict = torch.load("best_checkpoint/B1_best_checkpoint/best_unet_model.pth")
B1_model.load_state_dict(state_dict)

# %% [markdown]
# ## B2 Best Checkpoint

# %%
B2_model = NeuroUNET()    # create model instance
state_dict = torch.load("best_checkpoint/B2_best_checkpoint/best_unet_model.pth")
B2_model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
home = Path.home()
input_dir = home / 'em_capstone_f25' / 'test_images' / 'B2_test'
output_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B2_pred'

PredictTestSet(B2_model, input_dir=input_dir, output_dir=output_dir)
# Out:
# Found 81 images to process
# Processing B2_FOV00_Z075_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z075_pr_pred.tif
# Processing B2_FOV02_Z006_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z006_pr_pred.tif
# Processing B2_FOV03_Z042_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z042_pr_pred.tif
# Processing B2_FOV01_Z074_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z074_pr_pred.tif
# Processing B2_FOV03_Z073_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z073_pr_pred.tif
# Processing B2_FOV01_Z013_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z013_pr_pred.tif
# Processing B2_FOV03_Z070_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z070_pr_pred.tif
# Processing B2_FOV03_Z035_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z035_pr_pred.tif
# Processing B2_FOV00_Z035_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z035_pr_pred.tif
# Processing B2_FOV01_Z006_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z006_pr_pred.tif
# Processing B2_FOV02_Z039_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z039_pr_pred.tif
# Processing B2_FOV03_Z028_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z028_pr_pred.tif
# Processing B2_FOV02_Z038_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z038_pr_pred.tif
# Processing B2_FOV00_Z034_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z034_pr_pred.tif
# Processing B2_FOV03_Z089_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z089_pr_pred.tif
# Processing B2_FOV00_Z057_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z057_pr_pred.tif
# Processing B2_FOV01_Z031_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z031_pr_pred.tif
# Processing B2_FOV02_Z019_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z019_pr_pred.tif
# Processing B2_FOV03_Z055_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z055_pr_pred.tif
# Processing B2_FOV02_Z069_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z069_pr_pred.tif
# Processing B2_FOV02_Z007_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z007_pr_pred.tif
# Processing B2_FOV02_Z061_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z061_pr_pred.tif
# Processing B2_FOV01_Z052_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z052_pr_pred.tif
# Processing B2_FOV01_Z015_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z015_pr_pred.tif
# Processing B2_FOV03_Z022_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z022_pr_pred.tif
# Processing B2_FOV03_Z100_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z100_pr_pred.tif
# Processing B2_FOV00_Z023_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z023_pr_pred.tif
# Processing B2_FOV01_Z090_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z090_pr_pred.tif
# Processing B2_FOV00_Z049_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z049_pr_pred.tif
# Processing B2_FOV03_Z047_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z047_pr_pred.tif
# Processing B2_FOV03_Z063_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z063_pr_pred.tif
# Processing B2_FOV01_Z012_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z012_pr_pred.tif
# Processing B2_FOV03_Z029_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z029_pr_pred.tif
# Processing B2_FOV02_Z072_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z072_pr_pred.tif
# Processing B2_FOV01_Z014_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z014_pr_pred.tif
# Processing B2_FOV00_Z026_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z026_pr_pred.tif
# Processing B2_FOV02_Z040_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z040_pr_pred.tif
# Processing B2_FOV02_Z084_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z084_pr_pred.tif
# Processing B2_FOV00_Z089_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z089_pr_pred.tif
# Processing B2_FOV03_Z031_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z031_pr_pred.tif
# Processing B2_FOV01_Z021_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z021_pr_pred.tif
# Processing B2_FOV02_Z003_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z003_pr_pred.tif
# Processing B2_FOV01_Z020_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z020_pr_pred.tif
# Processing B2_FOV02_Z067_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z067_pr_pred.tif
# Processing B2_FOV02_Z050_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z050_pr_pred.tif
# Processing B2_FOV03_Z050_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z050_pr_pred.tif
# Processing B2_FOV00_Z000_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z000_pr_pred.tif
# Processing B2_FOV03_Z066_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z066_pr_pred.tif
# Processing B2_FOV00_Z081_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z081_pr_pred.tif
# Processing B2_FOV03_Z027_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z027_pr_pred.tif
# Processing B2_FOV00_Z072_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z072_pr_pred.tif
# Processing B2_FOV03_Z091_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z091_pr_pred.tif
# Processing B2_FOV01_Z018_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z018_pr_pred.tif
# Processing B2_FOV02_Z055_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z055_pr_pred.tif
# Processing B2_FOV01_Z044_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z044_pr_pred.tif
# Processing B2_FOV03_Z078_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z078_pr_pred.tif
# Processing B2_FOV01_Z076_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z076_pr_pred.tif
# Processing B2_FOV00_Z015_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z015_pr_pred.tif
# Processing B2_FOV00_Z090_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z090_pr_pred.tif
# Processing B2_FOV00_Z080_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z080_pr_pred.tif
# Processing B2_FOV00_Z003_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z003_pr_pred.tif
# Processing B2_FOV02_Z000_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z000_pr_pred.tif
# Processing B2_FOV00_Z020_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z020_pr_pred.tif
# Processing B2_FOV02_Z098_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z098_pr_pred.tif
# Processing B2_FOV00_Z096_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z096_pr_pred.tif
# Processing B2_FOV02_Z097_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z097_pr_pred.tif
# Processing B2_FOV03_Z003_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z003_pr_pred.tif
# Processing B2_FOV02_Z030_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z030_pr_pred.tif
# Processing B2_FOV01_Z054_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z054_pr_pred.tif
# Processing B2_FOV03_Z041_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z041_pr_pred.tif
# Processing B2_FOV02_Z053_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z053_pr_pred.tif
# Processing B2_FOV00_Z071_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z071_pr_pred.tif
# Processing B2_FOV02_Z036_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z036_pr_pred.tif
# Processing B2_FOV01_Z009_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV01_Z009_pr_pred.tif
# Processing B2_FOV03_Z092_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z092_pr_pred.tif
# Processing B2_FOV03_Z023_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z023_pr_pred.tif
# Processing B2_FOV02_Z054_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV02_Z054_pr_pred.tif
# Processing B2_FOV03_Z011_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z011_pr_pred.tif
# Processing B2_FOV03_Z082_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV03_Z082_pr_pred.tif
# Processing B2_FOV00_Z069_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z069_pr_pred.tif
# Processing B2_FOV00_Z017_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B2_pred/B2_FOV00_Z017_pr_pred.tif
# Completed processing 81 images

# %%
ground_truth = home / 'em_capstone_f25' / 'test_images' / 'B2_test'
pred_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B2_pred'
output_csv = str(home / 'em_capstone_f25' / 'neuro-ml-capstone' / 'test_results' / 'B2_pred_results.csv')

# write pearson corr coeff
PearsonCorrelationTestSet(ground_truth_dir=ground_truth, predicted_dir=pred_dir, output_csv=output_csv)
# Out:
# Found 81 ground truth images
# Calculating correlation for B2_FOV00_Z075_pr...
# Calculating correlation for B2_FOV02_Z006_pr...
# Calculating correlation for B2_FOV03_Z042_pr...
# Calculating correlation for B2_FOV01_Z074_pr...
# Calculating correlation for B2_FOV03_Z073_pr...
# Calculating correlation for B2_FOV01_Z013_pr...
# Calculating correlation for B2_FOV03_Z070_pr...
# Calculating correlation for B2_FOV03_Z035_pr...
# Calculating correlation for B2_FOV00_Z035_pr...
# Calculating correlation for B2_FOV01_Z006_pr...
# Calculating correlation for B2_FOV02_Z039_pr...
# Calculating correlation for B2_FOV03_Z028_pr...
# Calculating correlation for B2_FOV02_Z038_pr...
# Calculating correlation for B2_FOV00_Z034_pr...
# Calculating correlation for B2_FOV03_Z089_pr...
# Calculating correlation for B2_FOV00_Z057_pr...
# Calculating correlation for B2_FOV01_Z031_pr...
# Calculating correlation for B2_FOV02_Z019_pr...
# Calculating correlation for B2_FOV03_Z055_pr...
# Calculating correlation for B2_FOV02_Z069_pr...
# Calculating correlation for B2_FOV02_Z007_pr...
# Calculating correlation for B2_FOV02_Z061_pr...
# Calculating correlation for B2_FOV01_Z052_pr...
# Calculating correlation for B2_FOV01_Z015_pr...
# Calculating correlation for B2_FOV03_Z022_pr...
# Calculating correlation for B2_FOV03_Z100_pr...
# Calculating correlation for B2_FOV00_Z023_pr...
# Calculating correlation for B2_FOV01_Z090_pr...
# Calculating correlation for B2_FOV00_Z049_pr...
# Calculating correlation for B2_FOV03_Z047_pr...
# Calculating correlation for B2_FOV03_Z063_pr...
# Calculating correlation for B2_FOV01_Z012_pr...
# Calculating correlation for B2_FOV03_Z029_pr...
# Calculating correlation for B2_FOV02_Z072_pr...
# Calculating correlation for B2_FOV01_Z014_pr...
# Calculating correlation for B2_FOV00_Z026_pr...
# Calculating correlation for B2_FOV02_Z040_pr...
# Calculating correlation for B2_FOV02_Z084_pr...
# Calculating correlation for B2_FOV00_Z089_pr...
# Calculating correlation for B2_FOV03_Z031_pr...
# Calculating correlation for B2_FOV01_Z021_pr...
# Calculating correlation for B2_FOV02_Z003_pr...
# Calculating correlation for B2_FOV01_Z020_pr...
# Calculating correlation for B2_FOV02_Z067_pr...
# Calculating correlation for B2_FOV02_Z050_pr...
# Calculating correlation for B2_FOV03_Z050_pr...
# Calculating correlation for B2_FOV00_Z000_pr...
# Calculating correlation for B2_FOV03_Z066_pr...
# Calculating correlation for B2_FOV00_Z081_pr...
# Calculating correlation for B2_FOV03_Z027_pr...
# Calculating correlation for B2_FOV00_Z072_pr...
# Calculating correlation for B2_FOV03_Z091_pr...
# Calculating correlation for B2_FOV01_Z018_pr...
# Calculating correlation for B2_FOV02_Z055_pr...
# Calculating correlation for B2_FOV01_Z044_pr...
# Calculating correlation for B2_FOV03_Z078_pr...
# Calculating correlation for B2_FOV01_Z076_pr...
# Calculating correlation for B2_FOV00_Z015_pr...
# Calculating correlation for B2_FOV00_Z090_pr...
# Calculating correlation for B2_FOV00_Z080_pr...
# Calculating correlation for B2_FOV00_Z003_pr...
# Calculating correlation for B2_FOV02_Z000_pr...
# Calculating correlation for B2_FOV00_Z020_pr...
# Calculating correlation for B2_FOV02_Z098_pr...
# Calculating correlation for B2_FOV00_Z096_pr...
# Calculating correlation for B2_FOV02_Z097_pr...
# Calculating correlation for B2_FOV03_Z003_pr...
# Calculating correlation for B2_FOV02_Z030_pr...
# Calculating correlation for B2_FOV01_Z054_pr...
# Calculating correlation for B2_FOV03_Z041_pr...
# Calculating correlation for B2_FOV02_Z053_pr...
# Calculating correlation for B2_FOV00_Z071_pr...
# Calculating correlation for B2_FOV02_Z036_pr...
# Calculating correlation for B2_FOV01_Z009_pr...
# Calculating correlation for B2_FOV03_Z092_pr...
# Calculating correlation for B2_FOV03_Z023_pr...
# Calculating correlation for B2_FOV02_Z054_pr...
# Calculating correlation for B2_FOV03_Z011_pr...
# Calculating correlation for B2_FOV03_Z082_pr...
# Calculating correlation for B2_FOV00_Z069_pr...
# Calculating correlation for B2_FOV00_Z017_pr...
#
# Results saved to /home/WS_Tiger/em_capstone_f25/neuro-ml-capstone/test_results/B2_pred_results.csv
# Processed 81 image pairs
#
# Summary Statistics:
# Channel 1 Mean Correlation: 0.3947
# Channel 2 Mean Correlation: -0.4957
# Overall Mean Correlation: -0.0505

# %% [markdown]
# ## B3 Best Checkpoint

# %%
B3_model = NeuroUNET()    # create model instance
state_dict = torch.load("best_checkpoint/B3_best_checkpoint/best_unet_model.pth")
B3_model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
home = Path.home()
input_dir = home / 'em_capstone_f25' / 'test_images' / 'B3_test'
output_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B3_pred'

PredictTestSet(B3_model, input_dir=input_dir, output_dir=output_dir)
# Out:
# Found 54 images to process
# Processing B3_FOV01_Z049_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z049_pr_pred.tif
# Processing B3_FOV03_Z054_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z054_pr_pred.tif
# Processing B3_FOV02_Z004_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z004_pr_pred.tif
# Processing B3_FOV03_Z020_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z020_pr_pred.tif
# Processing B3_FOV02_Z063_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z063_pr_pred.tif
# Processing B3_FOV03_Z035_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z035_pr_pred.tif
# Processing B3_FOV01_Z051_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z051_pr_pred.tif
# Processing B3_FOV00_Z060_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z060_pr_pred.tif
# Processing B3_FOV03_Z022_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z022_pr_pred.tif
# Processing B3_FOV01_Z022_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z022_pr_pred.tif
# Processing B3_FOV00_Z045_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z045_pr_pred.tif
# Processing B3_FOV03_Z060_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z060_pr_pred.tif
# Processing B3_FOV01_Z019_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z019_pr_pred.tif
# Processing B3_FOV02_Z057_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z057_pr_pred.tif
# Processing B3_FOV00_Z033_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z033_pr_pred.tif
# Processing B3_FOV02_Z048_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z048_pr_pred.tif
# Processing B3_FOV01_Z035_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z035_pr_pred.tif
# Processing B3_FOV01_Z009_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z009_pr_pred.tif
# Processing B3_FOV02_Z019_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z019_pr_pred.tif
# Processing B3_FOV03_Z049_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z049_pr_pred.tif
# Processing B3_FOV01_Z024_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z024_pr_pred.tif
# Processing B3_FOV01_Z003_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z003_pr_pred.tif
# Processing B3_FOV00_Z053_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z053_pr_pred.tif
# Processing B3_FOV00_Z012_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z012_pr_pred.tif
# Processing B3_FOV03_Z010_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z010_pr_pred.tif
# Processing B3_FOV01_Z015_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z015_pr_pred.tif
# Processing B3_FOV00_Z009_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z009_pr_pred.tif
# Processing B3_FOV00_Z047_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z047_pr_pred.tif
# Processing B3_FOV02_Z034_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z034_pr_pred.tif
# Processing B3_FOV03_Z039_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z039_pr_pred.tif
# Processing B3_FOV00_Z010_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z010_pr_pred.tif
# Processing B3_FOV00_Z061_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z061_pr_pred.tif
# Processing B3_FOV01_Z006_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z006_pr_pred.tif
# Processing B3_FOV03_Z057_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z057_pr_pred.tif
# Processing B3_FOV03_Z016_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z016_pr_pred.tif
# Processing B3_FOV01_Z002_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z002_pr_pred.tif
# Processing B3_FOV02_Z065_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z065_pr_pred.tif
# Processing B3_FOV02_Z021_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z021_pr_pred.tif
# Processing B3_FOV02_Z038_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z038_pr_pred.tif
# Processing B3_FOV00_Z020_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z020_pr_pred.tif
# Processing B3_FOV02_Z022_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z022_pr_pred.tif
# Processing B3_FOV02_Z040_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z040_pr_pred.tif
# Processing B3_FOV02_Z020_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z020_pr_pred.tif
# Processing B3_FOV02_Z026_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z026_pr_pred.tif
# Processing B3_FOV00_Z031_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z031_pr_pred.tif
# Processing B3_FOV00_Z051_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z051_pr_pred.tif
# Processing B3_FOV02_Z053_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z053_pr_pred.tif
# Processing B3_FOV03_Z027_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV03_Z027_pr_pred.tif
# Processing B3_FOV00_Z015_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z015_pr_pred.tif
# Processing B3_FOV02_Z062_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z062_pr_pred.tif
# Processing B3_FOV01_Z017_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV01_Z017_pr_pred.tif
# Processing B3_FOV00_Z024_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV00_Z024_pr_pred.tif
# Processing B3_FOV02_Z056_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z056_pr_pred.tif
# Processing B3_FOV02_Z015_pr.tif...
# (4, 2189, 2189)
# Saved to /home/WS_Tiger/em_capstone_f25/test_predictions/B3_pred/B3_FOV02_Z015_pr_pred.tif
# Completed processing 54 images

# %%
ground_truth = home / 'em_capstone_f25' / 'test_images' / 'B3_test'
pred_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B3_pred'
output_csv = str(home / 'em_capstone_f25' / 'neuro-ml-capstone' / 'test_results' / 'B3_pred_results.csv')

# write pearson corr coeff
PearsonCorrelationTestSet(ground_truth_dir=ground_truth, predicted_dir=pred_dir, output_csv=output_csv)
# Out:
# Found 54 ground truth images
# Calculating correlation for B3_FOV01_Z049_pr...
# Calculating correlation for B3_FOV03_Z054_pr...
# Calculating correlation for B3_FOV02_Z004_pr...
# Calculating correlation for B3_FOV03_Z020_pr...
# Calculating correlation for B3_FOV02_Z063_pr...
# Calculating correlation for B3_FOV03_Z035_pr...
# Calculating correlation for B3_FOV01_Z051_pr...
# Calculating correlation for B3_FOV00_Z060_pr...
# Calculating correlation for B3_FOV03_Z022_pr...
# Calculating correlation for B3_FOV01_Z022_pr...
# Calculating correlation for B3_FOV00_Z045_pr...
# Calculating correlation for B3_FOV03_Z060_pr...
# Calculating correlation for B3_FOV01_Z019_pr...
# Calculating correlation for B3_FOV02_Z057_pr...
# Calculating correlation for B3_FOV00_Z033_pr...
# Calculating correlation for B3_FOV02_Z048_pr...
# Calculating correlation for B3_FOV01_Z035_pr...
# Calculating correlation for B3_FOV01_Z009_pr...
# Calculating correlation for B3_FOV02_Z019_pr...
# Calculating correlation for B3_FOV03_Z049_pr...
# Calculating correlation for B3_FOV01_Z024_pr...
# Calculating correlation for B3_FOV01_Z003_pr...
# Calculating correlation for B3_FOV00_Z053_pr...
# Calculating correlation for B3_FOV00_Z012_pr...
# Calculating correlation for B3_FOV03_Z010_pr...
# Calculating correlation for B3_FOV01_Z015_pr...
# Calculating correlation for B3_FOV00_Z009_pr...
# Calculating correlation for B3_FOV00_Z047_pr...
# Calculating correlation for B3_FOV02_Z034_pr...
# Calculating correlation for B3_FOV03_Z039_pr...
# Calculating correlation for B3_FOV00_Z010_pr...
# Calculating correlation for B3_FOV00_Z061_pr...
# Calculating correlation for B3_FOV01_Z006_pr...
# Calculating correlation for B3_FOV03_Z057_pr...
# Calculating correlation for B3_FOV03_Z016_pr...
# Calculating correlation for B3_FOV01_Z002_pr...
# Calculating correlation for B3_FOV02_Z065_pr...
# Calculating correlation for B3_FOV02_Z021_pr...
# Calculating correlation for B3_FOV02_Z038_pr...
# Calculating correlation for B3_FOV00_Z020_pr...
# Calculating correlation for B3_FOV02_Z022_pr...
# Calculating correlation for B3_FOV02_Z040_pr...
# Calculating correlation for B3_FOV02_Z020_pr...
# Calculating correlation for B3_FOV02_Z026_pr...
# Calculating correlation for B3_FOV00_Z031_pr...
# Calculating correlation for B3_FOV00_Z051_pr...
# Calculating correlation for B3_FOV02_Z053_pr...
# Calculating correlation for B3_FOV03_Z027_pr...
# Calculating correlation for B3_FOV00_Z015_pr...
# Calculating correlation for B3_FOV02_Z062_pr...
# Calculating correlation for B3_FOV01_Z017_pr...
# Calculating correlation for B3_FOV00_Z024_pr...
# Calculating correlation for B3_FOV02_Z056_pr...
# Calculating correlation for B3_FOV02_Z015_pr...
#
# Results saved to /home/WS_Tiger/em_capstone_f25/neuro-ml-capstone/test_results/B3_pred_results.csv
# Processed 54 image pairs
#
# Summary Statistics:
# Channel 1 Mean Correlation: 0.4965
# Channel 2 Mean Correlation: -0.5504
# Overall Mean Correlation: -0.0269
