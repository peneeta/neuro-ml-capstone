# %% [markdown]
# # Predict Test Set Images

# %%
from model import NeuroUNET
import torch
from pathlib import Path
from inference import PredictTestSet, PearsonCorrelationTestSet

# %% [markdown]
# ## B2 Best Checkpoint

# %%
B2_model = NeuroUNET()    # create model instance
state_dict = torch.load("best_checkpoint/B2_best_checkpoint/best_unet_model.pth")
B2_model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
home = Path.home()
input_dir = home / 'em_capstone_f25' / 'test_images' / 'B2_test'
output_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B2_pred'

PredictTestSet(B2_model, input_dir=input_dir, output_dir=output_dir)
# Out:
# Found 81 images to process
# Processing B2_FOV00_Z075_pr.tif...
# (4, 2189, 2189)
# (2, 128, 128)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 input_dir = home / 'em_capstone_f25' / 'test_images' / 'B2_test'
#       3 output_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B2_pred'
# ----> 5 PredictTestSet(B2_model, input_dir=input_dir, output_dir=output_dir)
#
# File ~/em_capstone_f25/neuro-ml-capstone/inference.py:87, in PredictTestSet(model, input_dir, output_dir, patch_size)
#      84 image = tiff.imread(img_file)
#      86 # Predict
# ---> 87 predicted = model.predict(image, patch_size=patch_size)
#      89 # Create output filename with _pred postfix
#      90 base_name = img_file.stem  # filename without extension
#
# File ~/em_capstone_f25/neuro-ml-capstone/model.py:171, in NeuroUNET.predict(self, image, patch_size)
#     168 patch_input = patch[[0, 3], :, :]
#     170 # Predict channels 1 and 2
# --> 171 patch_pred = self.predict(patch_input)
#     173 # Place predicted channels into output
#     174 output_padded[1:3, y_start:y_end, x_start:x_end] = patch_pred
#
# File ~/em_capstone_f25/neuro-ml-capstone/model.py:153, in NeuroUNET.predict(self, image, patch_size)
#     151 # Copy input channels 0 and 3 to output
#     152 output_padded[0, :, :] = padded[0, :, :]
# --> 153 output_padded[3, :, :] = padded[3, :, :]
#     155 # Process each patch
#     156 for i in range(n_patches_h):
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
ground_truth = home / 'em_capstone_f25' / 'test_images' / 'B2_test'
pred_dir = home / 'em_capstone_f25' / 'test_predictions' / 'B2_pred'
output_csv = home / 'em_capstone_f25' / 'neuro-ml-capstone' / 'test_results' / 'B2_pred_results.csv'

# write pearson corr coeff
PearsonCorrelationTestSet(ground_truth_dir=ground_truth, predicted_dir=pred_dir, output_csv=output_csv)
