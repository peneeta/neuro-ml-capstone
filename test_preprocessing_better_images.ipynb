# %% [markdown]
# # Testing preprocessing on images from wells B1, B2, and B3
# These images had better channel signal than the A1 image

# %%
import tifffile as tiff
import matplotlib.pyplot as plt
import numpy as np
import time
from image_preprocessing import Plot4Channel, MinimalPreprocessing

# %% [markdown]
# ## Look at B1

# %%
b1_test = "images/test_images/B1_FOV00_Z000.tif"
b1 = tiff.imread(b1_test)
Plot4Channel(b1)

# %%
b1_min = MinimalPreprocessing(b1)
Plot4Channel(b1_min)

# %% [markdown]
# ## Look at B2

# %%
b2_test = "images/test_images/B2_FOV00_Z005.tif"
b2 = tiff.imread(b2_test)
Plot4Channel(b2)

# %%
b2_min = MinimalPreprocessing(b2)
Plot4Channel(b2_min)

# %% [markdown]
# ## Look at B3

# %%
b3_test = "images/test_images/B3_FOV00_Z005.tif"
b3 = tiff.imread(b3_test)
Plot4Channel(b3)

# %%
b3_min = MinimalPreprocessing(b3)
Plot4Channel(b3_min)
